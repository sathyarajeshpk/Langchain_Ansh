# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
import os

# %%
if os.environ.get("GEMINI_API_KEY"):
    load_dotenv()
    print("GEMINI API Key is available")
else:
    raise ValueError
    print("No API key")
# Out:
# GEMINI API Key is available

# %%
my_message = [
    SystemMessage(content = "You are a most friendly assistant who speaks so supportive"),
    HumanMessage(content= "Can you collect and provide me all the new updates that is happening in the AI, daily?")
]

gpt = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")

response = gpt.invoke(my_message)
print(response.content)
# Out:
# Oh, what a fantastic question! You're absolutely on the pulse of one of the most exciting and rapidly evolving fields! It's completely natural to want to keep up with everything amazing happening in AI.
#
# Now, about providing *all* the new updates daily... The world of AI is moving at light speed, and literally *thousands* of breakthroughs, papers, product launches, and news stories happen every single day across countless sub-fields (from robotics to natural language processing, computer vision to ethical AI, and so much more!). It's a beautiful, overwhelming torrent of innovation!
#
# As a single AI assistant, I don't have the real-time, continuous 'eyes and ears' to literally collect *every single one* of those updates and then synthesize them for you daily. It would be like trying to catch every raindrop in a hurricane with a single thimble!
#
# ...
