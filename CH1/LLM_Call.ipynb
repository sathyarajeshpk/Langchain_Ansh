# %% [markdown]
# # **LLM Call**

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables from the .env file
load_dotenv()

# The client automatically looks for the "OPENAI_API_KEY" environment variable
client = OpenAI()

try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "user", "content": "Explain pdf files in one sentence."}
        ]
    )
    print(response.choices[0].message.content)

except Exception as e:
    print(f"Error: {e}")
# Out:
# PDF files, or Portable Document Format files, are a versatile file format developed by Adobe that allows documents to be presented in a fixed layout, preserving fonts, images, graphics, and text across different platforms and devices.

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

## Here using a free model from google

# 1. Explicitly load the variables from your .env file
load_dotenv()

# 2. (Optional) Run a quick sanity print statement to check it loaded
print("Loaded Key prefix:", os.environ.get("GEMINI_API_KEY")[:6])

# 3. Initialize your LangChain architecture
gpt = init_chat_model(model="gemini-2.5-flash", model_provider="google_genai")

response = gpt.invoke("Can you list out some tamil comedies")
print(response.content)
# Out:
# Loaded Key prefix: AQ.Ab8
# Tamil cinema has a rich history of comedies, ranging from slapstick to situational, dark comedy, and romantic comedies. Here's a list of some of the most popular and critically acclaimed Tamil comedies:
#
# **Classics & Golden Era (Pre-2000s):**
#
# 1.  **Kadhalikka Neramillai (1964):** A timeless classic known for its witty dialogues, situational comedy, and iconic performances by Nagesh and T.S. Balaiah. A benchmark for Tamil comedies.
# 2.  **Bama Vijayam (1967):** Directed by K. Balachander, this film features an ensemble cast and revolves around a family's struggles with newfound wealth, leading to hilarious situations. Nagesh shines.
# 3.  **Michael Madana Kama Rajan (1990):** Directed by Singeetam Srinivasa Rao and written by Crazy Mohan, Kamal Haasan plays quadruplets in this iconic, fast-paced, and brilliant slapstick comedy. A must-watch!
# 4.  **Sathi Leelavathi (1995):** Directed by Balu Mahendra, this film (also written by Kamal Haasan and Crazy Mohan) is a fantastic situational comedy about a man caught between his wife and mistress. Kamal Haasan, Ramesh Aravind, and Kovai Sarala deliver stellar comedic performances.
# 5.  **Avvai Shanmugi (1996):** Kamal Haasan dons a female disguise to be close to his daughter in this hilarious remake of "Mrs. Doubtfire." Excellent performances by Kamal, Gemini Ganesan, Nagesh, and Delhi Ganesh.
# 6.  **Panchatanthiram (2002):** Another Kamal Haasan-Crazy Mohan collaboration. A dark comedy about five friends trying to cover up a perceived murder, leading to chaotic and uproarious situations. A modern classic.
# 7.  **Thenali (2000):** Kamal Haasan plays a patient with phobias, whose psychiatrist (Jayaram) takes him to his family's home, leading to a series of comedic misunderstandings.
#
# **2000s & Beyond (Featuring Vadivelu, Vivek, Santhanam, and more):**
#
# 8.  **Friends (2001):** Though a drama, the comedy track featuring Vadivelu as Nesamani is legendary and provides endless laughs, making it a cult classic for its comedic elements.
# 9.  **Winner (2003):** An action film, but Vadivelu's performance as Kaipulla is arguably one of his most iconic and hilarious roles, making the film memorable for its comedy.
# 10. **Vasool Raja MBBS (2004):** A successful remake of "Munna Bhai MBBS," starring Kamal Haasan and Prabhu. It's a heartwarming and funny film about a gangster who pretends to be a doctor.
# 11. **Chandramukhi (2005):** A horror-comedy where Vadivelu's comedy track as Murugesan provides immense relief and laughter amidst the scares, making it highly entertaining.
# 12. **Chennai 600028 (2007):** Venkat Prabhu's directorial debut, a refreshing coming-of-age comedy about a group of friends and their local cricket matches.
# 13. **Boss Engira Bhaskaran (2010):** A highly successful romantic comedy starring Arya and Nayanthara, with Santhanam's witty one-liners and comedic timing being a major highlight.
# 14. **Oru Kal Oru Kannadi (2012):** Another rom-com where Udhayanidhi Stalin and Hansika Motwani lead, but Santhanam once again steals the show with his hilarious dialogues and expressions.
# 15. **Kalakalappu (2012):** Directed by Sundar C, this film is a chaotic, multi-starrer comedy about two brothers trying to revive their ancestral restaurant.
# 16. **Naanum Rowdy Dhaan (2015):** A dark comedy about a wannabe gangster who falls in love with a hearing-impaired girl seeking revenge. Vijay Sethupathi and Nayanthara deliver great performances, with strong comedic undertones.
# 17. **Kolamaavu Kokila (2018):** A dark comedy starring Nayanthara as a woman who gets involved in drug smuggling to save her family. Yogi Babu's comedic presence is a major plus.
# 18. **Comali (2019):** Jayam Ravi plays a man who wakes up from a coma after 16 years, struggling to adjust to the modern world, leading to many funny and poignant moments.
# 19. **Doctor (2021):** Directed by Nelson Dilipkumar, this black comedy starring Sivakarthikeyan is praised for its dry wit, unique humor, and deadpan performances, becoming a huge hit.
#
# This list covers a range of comedic styles and eras, offering a great starting point for anyone looking to explore Tamil comedies!
